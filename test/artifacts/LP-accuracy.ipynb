# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./lp_accuracy.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  n_nodes  n_edges  n_unique_training  accuracy
# 0           0        8       49                  1  0.562500
# 1           1        8       49                  2  0.546875
# 2           2        8       49                  3  0.531250
# 3           3        8       49                  4  0.546875
# 4           4        8       49                  4  0.546875

# %%
len(df)
# Out:
# 5718

# %%
sns.lmplot(x='n_edges', y='accuracy',
           ci=None,
           data=df)

# %%
sns.lmplot(x='n_unique_training', y='accuracy',
           hue='n_nodes',
           ci=None,
           data=df)
